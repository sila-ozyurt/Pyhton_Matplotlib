# %%
# scatter graph and histogram,boxplot
import numpy as np
import matplotlib.pyplot as plt

# %%
arr1=np.linspace(0,10,20)
arr2=arr1**3

# %%
plt.scatter(arr1,arr2)

# %%
#0 dan 100 e kadar random 50 tane sayı
newArr=np.random.randint(0,100,50)

# %%
plt.hist(arr2)
# Out:
# (array([9., 3., 1., 1., 2., 1., 0., 1., 1., 1.]),
#  array([   0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,
#          900., 1000.]),
#  <BarContainer object of 10 artists>)

# %%
#std yi daha iyi gözlemlemek için kullanılabilir
plt.boxplot((arr1))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14fd5c4fda0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14fd5be0290>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14fd5c4f770>],
#  'medians': [<matplotlib.lines.Line2D at 0x14fd5bfe930>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14fd5bff5f0>],
#  'means': []}
